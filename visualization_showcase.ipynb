# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 500)
y = np.cumsum(np.random.randn(500, 6), 0)

x,y
# Out:
# (array([ 0.        ,  0.02004008,  0.04008016,  0.06012024,  0.08016032,
#          0.1002004 ,  0.12024048,  0.14028056,  0.16032064,  0.18036072,
#          0.2004008 ,  0.22044088,  0.24048096,  0.26052104,  0.28056112,
#          0.3006012 ,  0.32064128,  0.34068136,  0.36072144,  0.38076152,
#          0.4008016 ,  0.42084168,  0.44088176,  0.46092184,  0.48096192,
#          0.501002  ,  0.52104208,  0.54108216,  0.56112224,  0.58116232,
#          0.6012024 ,  0.62124248,  0.64128257,  0.66132265,  0.68136273,
#          0.70140281,  0.72144289,  0.74148297,  0.76152305,  0.78156313,
#          0.80160321,  0.82164329,  0.84168337,  0.86172345,  0.88176353,
#          0.90180361,  0.92184369,  0.94188377,  0.96192385,  0.98196393,
#          1.00200401,  1.02204409,  1.04208417,  1.06212425,  1.08216433,
#          1.10220441,  1.12224449,  1.14228457,  1.16232465,  1.18236473,
#          1.20240481,  1.22244489,  1.24248497,  1.26252505,  1.28256513,
# ...

# %%
housing_df = pd.read_csv("City_Zhvi_AllHomes.csv")

# %%
housing_df
# Out:
#        Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0               0      6181         0     New York       City        NY    NY
# 1               1     12447         1  Los Angeles       City        CA    CA
# 2               2     39051         2      Houston       City        TX    TX
# 3               3     17426         3      Chicago       City        IL    IL
# 4               4      6915         4  San Antonio       City        TX    TX
# ...           ...       ...       ...          ...        ...       ...   ...
# 27325       27325     48550     29449       Winton       City        MN    MN
# 27326       27326     51821     29449  Eastabuchie       City        MS    MS
# 27327       27327    232607     29449         Dean       City        TX    TX
# 27328       27328      6638     29449      Pulaski       City        GA    GA
# 27329       27329     33089     29449    New Paris       City        PA    PA
#
# ...

# %%
housing_df = housing_df.drop(["Unnamed: 0", "SizeRank", "RegionID"], axis = 1)

# %%
housing_df.columns
# Out:
# Index(['RegionName', 'RegionType', 'StateName', 'State', 'Metro', 'CountyName',
#        '1996-01-31', '1996-02-29', '1996-03-31', '1996-04-30',
#        ...
#        '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31',
#        '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31'],
#       dtype='object', length=297)

# %%
used_df = housing_df.iloc[:, [0,1,2,3,4, -1]]
prices = housing_df.iloc[:, 6:]

# %%
prices.iloc[0]
# Out:
# 1996-01-31    196258.0
# 1996-02-29    195693.0
# 1996-03-31    195383.0
# 1996-04-30    194836.0
# 1996-05-31    194652.0
#                 ...
# 2019-11-30    654394.0
# 2019-12-31    653930.0
# 2020-01-31    653901.0
# 2020-02-29    653565.0
# 2020-03-31    652307.0
# Name: 0, Length: 291, dtype: float64

# %%
used_df = used_df.rename(columns = {"2020-03-31" : "price"})

# %%
used_df
# Out:
#         RegionName RegionType StateName State  \
# 0         New York       City        NY    NY
# 1      Los Angeles       City        CA    CA
# 2          Houston       City        TX    TX
# 3          Chicago       City        IL    IL
# 4      San Antonio       City        TX    TX
# ...            ...        ...       ...   ...
# 27325       Winton       City        MN    MN
# 27326  Eastabuchie       City        MS    MS
# 27327         Dean       City        TX    TX
# 27328      Pulaski       City        GA    GA
# 27329    New Paris       City        PA    PA
#
#                                   Metro     price
# 0           New York-Newark-Jersey City  652307.0
# 1        Los Angeles-Long Beach-Anaheim  752508.0
# 2      Houston-The Woodlands-Sugar Land  191907.0
# 3              Chicago-Naperville-Elgin  249152.0
# 4             San Antonio-New Braunfels  187718.0
# ...                                 ...       ...
# 27325                            Duluth   70399.0
# ...

# %%
used_df.RegionName = pd.Categorical(used_df.RegionName).codes
used_df.RegionType = pd.Categorical(used_df.RegionType).codes
used_df.StateName = pd.Categorical(used_df.StateName).codes
used_df.State = pd.Categorical(used_df.State).codes
used_df = used_df.drop("Metro", axis = 1)

# %%
used_df
# Out:
#        RegionName  RegionType  StateName  State     price
# 0           10634           0         34     34  652307.0
# 1            8751           0          4      4  752508.0
# 2            7010           0         43     43  191907.0
# 3            2673           0         14     14  249152.0
# 4           13487           0         43     43  187718.0
# ...           ...         ...        ...    ...       ...
# 27325       17332           0         23     23   70399.0
# 27326        4357           0         25     25   82284.0
# 27327        3696           0         43     43  182361.0
# 27328       12455           0         10     10  100464.0
# 27329       10584           0         38     38   93564.0
#
# [27330 rows x 5 columns]

# %%
cumsum = np.cumsum(used_df["price"])

# %%
plt.plot(prices.iloc[0])
plt.legend("p", loc='upper left');
plt.title("price by year")
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
import seaborn as sns
sns.set()

# %%
plt.plot(prices.iloc[0])
plt.legend("p", loc='upper left');
plt.title("price by year")
plt.xlabel('time')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
for col in [0, 1, 3]:
    plt.hist(prices.iloc[col],  alpha=0.6)
plt.legend('ABC')

# %%
prices
# Out:
#        1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  1996-06-30  \
# 0        196258.0    195693.0    195383.0    194836.0    194652.0    194520.0
# 1        185649.0    185625.0    185645.0    185706.0    185755.0    185852.0
# 2         93518.0     93633.0     93636.0     93811.0     93966.0     94079.0
# 3        130920.0    130772.0    130511.0    130495.0    130172.0    130291.0
# 4         94041.0     94007.0     93973.0     93957.0     93895.0     93880.0
# ...           ...         ...         ...         ...         ...         ...
# 27325         NaN         NaN         NaN         NaN         NaN         NaN
# 27326         NaN         NaN         NaN         NaN         NaN         NaN
# 27327         NaN         NaN         NaN         NaN         NaN         NaN
# 27328         NaN         NaN         NaN         NaN         NaN         NaN
# 27329         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
for col in [0, 1, 3]:
    sns.kdeplot(prices.iloc[col])
plt.legend('ABC')

# %%
for col in [0, 1]:
    sns.displot(prices.iloc[col])

# %%
sns.kdeplot(prices.iloc[0]);

# %%
with sns.axes_style('white'):
    sns.jointplot(prices.iloc[0], prices.iloc[1], prices, kind='kde');
# Out:
# /home/bencebogdndy/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(used_df);

# %%
sns.jointplot(prices.columns[1], prices.columns[0], data=prices, kind='reg');
# Out:
# /home/bencebogdndy/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
wine_df=pd.read_csv("wine.csv")

# %%
wine_df.drop("Id", axis= 1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
sns.pairplot(wine_df, hue="quality")

# %%
with sns.axes_style('white'):
    sns.jointplot(x = wine_df.columns[0], y= wine_df.columns[1], data = wine_df, kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot(x = wine_df.columns[2], y= wine_df.columns[3], data = wine_df, kind='hex');

# %%
sns.jointplot(x = wine_df.columns[7], y= wine_df.columns[8], data = wine_df, kind='reg');

# %%
sns.violinplot("quality", "density", data=wine_df,
               palette=["lightblue", "lightpink"], inner="quartile", split=True);
# Out:
# /home/bencebogdndy/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
